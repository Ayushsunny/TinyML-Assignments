# %%
# Dataset from github
# !git clone https://github.com/zalandoresearch/fashion-mnist.git
# Out:
# Cloning into 'fashion-mnist'...
# remote: Enumerating objects: 762, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 762 (delta 0), reused 2 (delta 0), pack-reused 758
# Receiving objects: 100% (762/762), 105.85 MiB | 25.90 MiB/s, done.
# Resolving deltas: 100% (444/444), done.

# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loaded the Fashion MNIST dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Normalizing the input data
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# %%
# Reshaping the input data
X_train = X_train.reshape(-1, 28 * 28)
X_test = X_test.reshape(-1, 28 * 28)

# %%
# Defining the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(28 * 28,)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the model
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 938/938 [==============================] - 9s 7ms/step - loss: 0.9477 - accuracy: 0.6717 - val_loss: 0.5571 - val_accuracy: 0.8117
# Epoch 2/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.5609 - accuracy: 0.8033 - val_loss: 0.4690 - val_accuracy: 0.8391
# Epoch 3/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.4855 - accuracy: 0.8286 - val_loss: 0.4335 - val_accuracy: 0.8481
# Epoch 4/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.4408 - accuracy: 0.8436 - val_loss: 0.4119 - val_accuracy: 0.8544
# Epoch 5/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.4151 - accuracy: 0.8530 - val_loss: 0.3903 - val_accuracy: 0.8614
# Epoch 6/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3953 - accuracy: 0.8589 - val_loss: 0.3862 - val_accuracy: 0.8604
# Epoch 7/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3804 - accuracy: 0.8651 - val_loss: 0.3782 - val_accuracy: 0.8637
# Epoch 8/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.3655 - accuracy: 0.8691 - val_loss: 0.3675 - val_accuracy: 0.8685
# Epoch 9/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.3562 - accuracy: 0.8717 - val_loss: 0.3561 - val_accuracy: 0.8705
# Epoch 10/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.3453 - accuracy: 0.8763 - val_loss: 0.3510 - val_accuracy: 0.8743
# Epoch 11/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.3359 - accuracy: 0.8789 - val_loss: 0.3466 - val_accuracy: 0.8756
# Epoch 12/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.3324 - accuracy: 0.8792 - val_loss: 0.3501 - val_accuracy: 0.8751
# Epoch 13/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.3224 - accuracy: 0.8844 - val_loss: 0.3354 - val_accuracy: 0.8797
# Epoch 14/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.3164 - accuracy: 0.8837 - val_loss: 0.3370 - val_accuracy: 0.8810
# Epoch 15/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3092 - accuracy: 0.8872 - val_loss: 0.3353 - val_accuracy: 0.8826
# Epoch 16/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3047 - accuracy: 0.8903 - val_loss: 0.3308 - val_accuracy: 0.8809
# Epoch 17/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2989 - accuracy: 0.8908 - val_loss: 0.3309 - val_accuracy: 0.8806
# Epoch 18/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2931 - accuracy: 0.8914 - val_loss: 0.3255 - val_accuracy: 0.8856
# Epoch 19/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2888 - accuracy: 0.8942 - val_loss: 0.3247 - val_accuracy: 0.8854
# Epoch 20/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2825 - accuracy: 0.8970 - val_loss: 0.3281 - val_accuracy: 0.8834
# Epoch 21/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2797 - accuracy: 0.8981 - val_loss: 0.3284 - val_accuracy: 0.8839
# Epoch 22/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2745 - accuracy: 0.8988 - val_loss: 0.3177 - val_accuracy: 0.8872
# Epoch 23/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2716 - accuracy: 0.9001 - val_loss: 0.3178 - val_accuracy: 0.8890
# Epoch 24/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2662 - accuracy: 0.9027 - val_loss: 0.3157 - val_accuracy: 0.8895
# Epoch 25/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2653 - accuracy: 0.9032 - val_loss: 0.3154 - val_accuracy: 0.8868
# Epoch 26/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2611 - accuracy: 0.9026 - val_loss: 0.3187 - val_accuracy: 0.8882
# Epoch 27/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2547 - accuracy: 0.9054 - val_loss: 0.3174 - val_accuracy: 0.8875
# Epoch 28/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2525 - accuracy: 0.9062 - val_loss: 0.3132 - val_accuracy: 0.8913
# Epoch 29/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2519 - accuracy: 0.9069 - val_loss: 0.3150 - val_accuracy: 0.8925
# Epoch 30/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2459 - accuracy: 0.9089 - val_loss: 0.3114 - val_accuracy: 0.8911
# Epoch 31/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2403 - accuracy: 0.9107 - val_loss: 0.3070 - val_accuracy: 0.8949
# Epoch 32/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2411 - accuracy: 0.9103 - val_loss: 0.3140 - val_accuracy: 0.8901
# Epoch 33/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2367 - accuracy: 0.9119 - val_loss: 0.3124 - val_accuracy: 0.8907
# Epoch 34/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2358 - accuracy: 0.9132 - val_loss: 0.3078 - val_accuracy: 0.8925
# Epoch 35/50
# 938/938 [==============================] - 5s 6ms/step - loss: 0.2315 - accuracy: 0.9135 - val_loss: 0.3137 - val_accuracy: 0.8914
# Epoch 36/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2284 - accuracy: 0.9161 - val_loss: 0.3122 - val_accuracy: 0.8952
# Epoch 37/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2262 - accuracy: 0.9161 - val_loss: 0.3129 - val_accuracy: 0.8929
# Epoch 38/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2247 - accuracy: 0.9161 - val_loss: 0.3074 - val_accuracy: 0.8939
# Epoch 39/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2235 - accuracy: 0.9172 - val_loss: 0.3066 - val_accuracy: 0.8963
# Epoch 40/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2199 - accuracy: 0.9188 - val_loss: 0.3084 - val_accuracy: 0.8949
# Epoch 41/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2150 - accuracy: 0.9202 - val_loss: 0.3059 - val_accuracy: 0.8938
# Epoch 42/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2154 - accuracy: 0.9204 - val_loss: 0.3074 - val_accuracy: 0.8937
# Epoch 43/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2113 - accuracy: 0.9219 - val_loss: 0.3090 - val_accuracy: 0.8943
# Epoch 44/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2084 - accuracy: 0.9214 - val_loss: 0.3080 - val_accuracy: 0.8968
# Epoch 45/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2064 - accuracy: 0.9216 - val_loss: 0.3121 - val_accuracy: 0.8970
# Epoch 46/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2049 - accuracy: 0.9230 - val_loss: 0.3096 - val_accuracy: 0.8953
# Epoch 47/50
# 938/938 [==============================] - 8s 9ms/step - loss: 0.2045 - accuracy: 0.9239 - val_loss: 0.3160 - val_accuracy: 0.8951
# Epoch 48/50
# 938/938 [==============================] - 5s 5ms/step - loss: 0.2026 - accuracy: 0.9237 - val_loss: 0.3079 - val_accuracy: 0.8978
# Epoch 49/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1973 - accuracy: 0.9273 - val_loss: 0.3138 - val_accuracy: 0.8962
# Epoch 50/50
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1966 - accuracy: 0.9262 - val_loss: 0.3080 - val_accuracy: 0.8978

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f'Test accuracy: {test_acc:.2f}')
print(f'Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.90
# Test loss: 0.31

# %%
# Plotting the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
